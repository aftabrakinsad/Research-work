# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats
from collections import Counter
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import statsmodels.api as sm
from statsmodels.formula.api import ols
from tabulate import tabulate

df = pd.read_csv('Security Analysis in OTS.csv')

# %%
age_group_counts = df['Age'].value_counts().reset_index()
age_group_counts.columns = ['Age', 'User_Count']
total_users = len(df)
age_group_counts['Percentage'] = (age_group_counts['User_Count'] / total_users) * 100

plt.figure(figsize=(10, 5))
ax = plt.gca()

colors = ['blue', 'green', 'orange', 'red', 'purple', 'pink', 'brown', 'gray', 'cyan', 'magenta']

bars = plt.bar(age_group_counts['Age'], age_group_counts['User_Count'], color=colors[:len(age_group_counts)])

for bar, count, percent in zip(bars, age_group_counts['User_Count'], age_group_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Age Group')
plt.ylabel('Count')

plt.xticks(rotation=0)

plt.show()

# %%
gender_counts = df['Gender'].value_counts().reset_index()
gender_counts.columns = ['Gender', 'User Count']

total_users = len(df)
gender_counts['Percentage'] = (gender_counts['User Count'] / total_users) * 100

plt.figure(figsize=(5, 5))
ax = plt.gca()

colors = ['green', 'pink', 'blue', 'orange']

bars = plt.bar(gender_counts['Gender'], gender_counts['User Count'], color=colors[:len(gender_counts)])

for bar, count, percent in zip(bars, gender_counts['User Count'], gender_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Gender')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()

# %%
education_counts = df['Education'].value_counts().reset_index()
education_counts.columns = ['Education', 'User Count']
total_users = len(df)
education_counts['Percentage'] = (education_counts['User Count'] / total_users) * 100

plt.figure(figsize=(10, 5))
ax = plt.gca()

colors = ['blue', 'green', 'orange', 'red', 'purple', 'pink', 'brown', 'gray', 'cyan', 'magenta']

bars = plt.bar(education_counts['Education'], education_counts['User Count'], color=colors[:len(education_counts)])

for bar, count, percent in zip(bars, education_counts['User Count'], education_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Education Level')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()

# %%
occupation_counts = df['Occupation'].value_counts().reset_index()

occupation_counts.columns = ['Occupation', 'User Count']

total_users = len(df)
occupation_counts['Percentage'] = (occupation_counts['User Count'] / total_users) * 100

plt.figure(figsize=(10, 5))
ax = plt.gca()

colors = ['blue', 'green', 'orange', 'pink', 'purple', 'red', 'brown', 'gray', 'cyan', 'magenta']

bars = plt.bar(occupation_counts['Occupation'], occupation_counts['User Count'], color=colors[:len(education_counts)])

for bar, count, percent in zip(bars, occupation_counts['User Count'], occupation_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Occupation')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()

# %%
msbdt_counts = df['Spending'].value_counts().reset_index()

msbdt_counts.columns = ['Spending', 'User Count']

total_users = len(df)
msbdt_counts['Percentage'] = (msbdt_counts['User Count'] / total_users) * 100

plt.figure(figsize=(12, 5))
ax = plt.gca()

bars = plt.bar(msbdt_counts['Spending'], msbdt_counts['User Count'])

for bar, count, percent in zip(bars, msbdt_counts['User Count'], msbdt_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Monthly Spending BDT')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()

# %%
uot_counts = df['Use_online_trans'].value_counts().reset_index()

uot_counts.columns = ['Use_online_trans', 'User Count']

total_users = len(df)
uot_counts['Percentage'] = (uot_counts['User Count'] / total_users) * 100

plt.figure(figsize=(2, 5))
ax = plt.gca()

bars = plt.bar(uot_counts['Use_online_trans'], uot_counts['User Count'])

for bar, count, percent in zip(bars, uot_counts, uot_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count}\n({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('OTS uses')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()

# %%
AOYA_counts = df['AOYA'].value_counts().reset_index()

AOYA_counts.columns = ['AOYA', 'User Count']

total_users = len(df)
AOYA_counts['Percentage'] = (AOYA_counts['User Count'] / total_users) * 100

print(AOYA_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(AOYA_counts['AOYA'], AOYA_counts['User Count'])

for bar, count, percent in zip(bars, AOYA_counts['User Count'], AOYA_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Anyone Helped to Create Account')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#   AOYA  User Count  Percentage
# 0   No         241       60.25
# 1  Yes         159       39.75

# %%
TC_counts = df['TC'].value_counts().reset_index()

TC_counts.columns = ['TC', 'User Count']

total_users = len(df)
TC_counts['Percentage'] = (TC_counts['User Count'] / total_users) * 100

print(TC_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(TC_counts['TC'], TC_counts['User Count'])

for bar, count, percent in zip(bars, TC_counts['User Count'], TC_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Reading Terms & Condition')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#     TC  User Count  Percentage
# 0   No         353       88.25
# 1  Yes          47       11.75

# %%
LATC_counts = df['LATC'].value_counts().reset_index()

LATC_counts.columns = ['LATC', 'User Count']

total_users = len(df)
LATC_counts['Percentage'] = (uot_counts['User Count'] / total_users) * 100

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(LATC_counts['LATC'], LATC_counts['User Count'])

for bar, count, percent in zip(bars, LATC_counts, LATC_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count}\n({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Lack of Awareness not Reading Terms & Condition')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()

# %%
MC_counts = df['MC'].value_counts().reset_index()

MC_counts.columns = ['MC', 'User Count']

total_users = len(df)
MC_counts['Percentage'] = (TC_counts['User Count'] / total_users) * 100

print(MC_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(MC_counts['MC'], MC_counts['User Count'])

for bar, count, percent in zip(bars, MC_counts['User Count'], MC_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Daily Mobile Message Checking')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#     MC  User Count  Percentage
# 0   No         281       88.25
# 1  Yes         119       11.75

# %%
a_Scams_counts = df['a_Scams'].value_counts().reset_index()

a_Scams_counts.columns = ['a_Scams', 'User Count']

total_users = len(df)
a_Scams_counts['Percentage'] = (a_Scams_counts['User Count'] / total_users) * 100

print(a_Scams_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(a_Scams_counts['a_Scams'], a_Scams_counts['User Count'])

for bar, count, percent in zip(bars, a_Scams_counts['User Count'], a_Scams_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Scam Awareness')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#   a_Scams  User Count  Percentage
# 0      No         282        70.5
# 1     Yes         118        29.5

# %%
a_Fraud_counts = df['a_Fraud'].value_counts().reset_index()

a_Fraud_counts.columns = ['a_Fraud', 'User Count']

total_users = len(df)
a_Fraud_counts['Percentage'] = (a_Fraud_counts['User Count'] / total_users) * 100

print(a_Fraud_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(a_Fraud_counts['a_Fraud'], a_Fraud_counts['User Count'])

for bar, count, percent in zip(bars, a_Scams_counts['User Count'], a_Scams_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Fraud Awareness')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#   a_Fraud  User Count  Percentage
# 0      No         277       69.25
# 1     Yes         123       30.75

# %%
a_Identity_Theft_counts = df['a_Identity_Theft'].value_counts().reset_index()

a_Identity_Theft_counts.columns = ['a_Identity_Theft', 'User Count']

total_users = len(df)
a_Identity_Theft_counts['Percentage'] = (a_Identity_Theft_counts['User Count'] / total_users) * 100

print(a_Identity_Theft_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(a_Identity_Theft_counts['a_Identity_Theft'], a_Identity_Theft_counts['User Count'])

for bar, count, percent in zip(bars, a_Identity_Theft_counts['User Count'], a_Identity_Theft_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Identity Theft Awareness')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#   a_Identity_Theft  User Count  Percentage
# 0               No         277       69.25
# 1              Yes         123       30.75

# %%
a_Phishing_counts = df['a_Phishing'].value_counts().reset_index()

a_Phishing_counts.columns = ['a_Phishing', 'User Count']

total_users = len(df)
a_Phishing_counts['Percentage'] = (a_Phishing_counts['User Count'] / total_users) * 100

print(a_Phishing_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(a_Phishing_counts['a_Phishing'], a_Phishing_counts['User Count'])

for bar, count, percent in zip(bars, a_Phishing_counts['User Count'], a_Phishing_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Phishing Awareness')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#   a_Phishing  User Count  Percentage
# 0         No         277       69.25
# 1        Yes         123       30.75

# %%
a_Hacking_counts = df['a_Hacking'].value_counts().reset_index()

a_Hacking_counts.columns = ['a_Hacking', 'User Count']

total_users = len(df)
a_Hacking_counts['Percentage'] = (a_Hacking_counts['User Count'] / total_users) * 100

print(a_Hacking_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(a_Hacking_counts['a_Hacking'], a_Hacking_counts['User Count'])

for bar, count, percent in zip(bars, a_Hacking_counts['User Count'], a_Hacking_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Hacking Awareness')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#   a_Hacking  User Count  Percentage
# 0       Yes         237       59.25
# 1        No         163       40.75

# %%
DPL_counts = df['DPL'].value_counts().reset_index()

DPL_counts.columns = ['DPL', 'User Count']

total_users = len(df)
DPL_counts['Percentage'] = (DPL_counts['User Count'] / total_users) * 100

print(DPL_counts)

plt.figure(figsize=(5, 5))
ax = plt.gca()

bars = plt.bar(DPL_counts['DPL'], DPL_counts['User Count'])

for bar, count, percent in zip(bars, DPL_counts['User Count'], DPL_counts['Percentage']):
    height = bar.get_height()
    ax.annotate(f'{count} ({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel('Awareness of Data Protection Law')
plt.ylabel('User Count')

plt.xticks(rotation=0)

plt.show()
# Out:
#    DPL  User Count  Percentage
# 0   No         312        78.0
# 1  Yes          88        22.0

# %%
MBS_columns = ['bKash', 'Nagad', 'Rocket', 'SureCash', 'Upay', 'Trust Axiata Pay (Tap)', 'City Touch', 'EBL SKYBANKING', 'NexusPay', 'MTB Smart Banking', 'CellFin', 'My Prime']

for col in MBS_columns:
    df[col] = df['MBS'].apply(lambda x: col in x).astype(int)

MBS_counts = df[MBS_columns].sum()

MBS_counts = MBS_counts.sort_values(ascending=False)
MBS_issues = MBS_counts.sum()

MBS_percentages = (MBS_counts / MBS_issues) * 100

MBS_percentages_sorted = MBS_percentages.sort_values(ascending=False)

print(MBS_counts)
print(MBS_percentages_sorted)

fig, ax = plt.subplots(figsize=(18, 10))

bars = ax.bar(MBS_counts.index, MBS_counts, color='skyblue')

plt.xlabel('Mobile Banking Apps')
plt.ylabel('Count')

for bar, count, percent in zip(bars, MBS_counts, MBS_percentages_sorted):
    height = bar.get_height()
    ax.annotate(f'{count}\n({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# bKash                     268
# Rocket                    252
# CellFin                   162
# My Prime                   60
# Nagad                      50
# Upay                       19
# SureCash                   15
# Trust Axiata Pay (Tap)      0
# City Touch                  0
# EBL SKYBANKING              0
# NexusPay                    0
# MTB Smart Banking           0
# dtype: int64
# bKash                     32.445521
# Rocket                    30.508475
# CellFin                   19.612591
# My Prime                   7.263923
# Nagad                      6.053269
# Upay                       2.300242
# SureCash                   1.815981
# Trust Axiata Pay (Tap)     0.000000
# City Touch                 0.000000
# EBL SKYBANKING             0.000000
# NexusPay                   0.000000
# MTB Smart Banking          0.000000
# dtype: float64

# %%
S_Problems_columns = ['Scam', 'Fraud', 'Hacking', 'Phishing', 'Identity Theft', 'None']

for col in S_Problems_columns:
    if col == 'None':
        df[col] = df['S_Problems'].apply(lambda x: pd.isna(x) or x.strip() == 'None').astype(int)
    else:
        df[col] = df['S_Problems'].apply(lambda x: col in str(x) if pd.notna(x) else False).astype(int)

S_Problems_counts = df[S_Problems_columns].sum()

S_Problems_issues = S_Problems_counts.sum()
S_Problems_percentages = (S_Problems_counts / S_Problems_issues) * 100

S_Problems_counts = S_Problems_counts.sort_values(ascending=False)
S_Problems_percentages_sorted = S_Problems_percentages.sort_values(ascending=False)

print(S_Problems_counts)
print(S_Problems_percentages_sorted)

fig, ax = plt.subplots(figsize=(18, 9))
bars = ax.bar(S_Problems_counts.index, S_Problems_counts, color='skyblue')

plt.xlabel('Security Problem Faced by Users')
plt.ylabel('Count')

for bar, count, percent in zip(bars, S_Problems_counts, S_Problems_percentages_sorted):
    height = bar.get_height()
    ax.annotate(f'{count}\n({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Scam              252
# Phishing          243
# Hacking           208
# Identity Theft    197
# Fraud             176
# None              140
# dtype: int64
# Scam              20.723684
# Phishing          19.983553
# Hacking           17.105263
# Identity Theft    16.200658
# Fraud             14.473684
# None              11.513158
# dtype: float64

# %%
O_Problems_columns = ['OTP', 'QR Scan', 'Connectivity','None']

for col in O_Problems_columns:
    df[col] = df['O_Problems'].apply(lambda x: col in x).astype(int)

O_Problems_counts = df[O_Problems_columns].sum()

O_Problems_counts = O_Problems_counts.sort_values(ascending=False)
O_Problems_issues = O_Problems_counts.sum()

O_Problems_percentages = (O_Problems_counts / O_Problems_issues) * 100

O_Problems_percentages_sorted = O_Problems_percentages.sort_values(ascending=False)

print(O_Problems_counts)
print(O_Problems_percentages_sorted)

fig, ax = plt.subplots(figsize=(18, 9))

bars = ax.bar(O_Problems_counts.index, O_Problems_counts, color='skyblue')

plt.xlabel('Other Problems Faced by Users')
plt.ylabel('Count')

for bar, count, percent in zip(bars, O_Problems_counts, O_Problems_percentages_sorted):
    height = bar.get_height()
    ax.annotate(f'{count}\n({percent:.2f}%)',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# OTP             277
# QR Scan         172
# Connectivity    104
# None              0
# dtype: int64
# OTP             50.090416
# QR Scan         31.103074
# Connectivity    18.806510
# None             0.000000
# dtype: float64

# %%
df['Spending'] = df['Spending'].str.split(' - ').apply(lambda x: (int(x[0]) + int(x[1])) / 2)

statistics = df[['Spending', 'S_ratings']].agg(['mean', 'median', 'std', 'min', 'max'])

print(statistics)
# Out:
#             Spending  S_ratings
# mean    16354.375000     5.0400
# median   7500.000000     5.0000
# std     23204.891555     1.4504
# min       250.000000     2.0000
# max     75000.000000     8.0000

# %%
s_problems_column_numeric = df['scam_Problems']

count = s_problems_column_numeric.count()
mean = s_problems_column_numeric.mean()
median = s_problems_column_numeric.median()
std = s_problems_column_numeric.std()
min_value = s_problems_column_numeric.min()
max_value = s_problems_column_numeric.max()

print("Count:", count)
print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std)
print("Minimum:", min_value)
print("Maximum:", max_value)
# Out:
# Count: 400
# Mean: 0.6275
# Median: 1.0
# Standard Deviation: 0.4840760001640622
# Minimum: 0
# Maximum: 1

# %%
num_users_high_school = 0
num_users_bachelors = 0
num_users_masters = 0
num_users_phd = 0

education_categories = ["High School or Less", "Bachelor's Degree", "Master's Degree", "Ph.D."]
num_users_by_education = []

for education_category in education_categories:
    filtered_df = df[(df['Education'] == education_category) & (df['S_Problems'] != 'None')]
    num_users = len(filtered_df)
    num_users_by_education.append(num_users)

total_users = len(df[df['S_Problems'] != 'None'])
percentages = [(count / total_users) * 100 for count in num_users_by_education]

table = {
    'Education Level': education_categories,
    'Percentage of Users Facing Problems': [f'{percentage:.2f}%' for percentage in percentages]
}

print(tabulate(table, headers="keys", tablefmt="grid"))

plt.figure(figsize=(10, 8))
plt.plot(education_categories, percentages, marker='o', linestyle='-', color='skyblue')
plt.xlabel('Education Level', fontweight='bold', fontsize=15)
plt.ylabel('Percentage of Users Facing Problems', fontweight='bold', fontsize=15)
plt.xticks(rotation=0)
plt.grid(True)

for i, percentage in enumerate(percentages):
    plt.annotate(f'{percentage:.2f}%', (education_categories[i], percentages[i]), textcoords="offset points", xytext=(0, 10), ha='center')

plt.show()
# Out:
# +---------------------+---------------------------------------+
# | Education Level     | Percentage of Users Facing Problems   |
# +=====================+=======================================+
# | High School or Less | 35.00%                                |
# +---------------------+---------------------------------------+
# | Bachelor's Degree   | 30.00%                                |
# +---------------------+---------------------------------------+
# | Master's Degree     | 22.50%                                |
# +---------------------+---------------------------------------+
# | Ph.D.               | 12.50%                                |
# +---------------------+---------------------------------------+

# %%
filtered_df = df[df['S_Problems'] != 'None']

num_users_facing_problems = len(filtered_df)

num_males = len(filtered_df[filtered_df['Gender'] == 'Male'])
num_females = len(filtered_df[filtered_df['Gender'] == 'Female'])

print(f"Number of users facing problems: {num_users_facing_problems}")
print(f"Number of males facing problems: {num_males}")
print(f"Number of females facing problems: {num_females}")
# Out:
# Number of users facing problems: 400
# Number of males facing problems: 245
# Number of females facing problems: 155

# %%
filtered_df = df[df['S_Problems'] != 'None']

grouped = filtered_df.groupby(['Education', 'Gender']).size().unstack(fill_value=0)

print("Number of users facing problems by Education and Gender:")
print(grouped)
# Out:
# Number of users facing problems by Education and Gender:
# Gender               Female  Male
# Education
# Bachelor's Degree        70    50
# High School or Less      42    98
# Master's Degree          24    66
# Ph.D.                    19    31

# %%
filtered_df = df[df['S_Problems'] != 'None']

grouped = filtered_df.groupby(['Education', 'Gender']).size().unstack(fill_value=0)

total_users = grouped.sum().sum()

percentage_grouped = (grouped / total_users) * 100

print("Percentage of users facing problems by Education and Gender:")
print(percentage_grouped)
print(grouped)
# Out:
# Percentage of users facing problems by Education and Gender:
# Gender               Female   Male
# Education
# Bachelor's Degree     17.50  12.50
# High School or Less   10.50  24.50
# Master's Degree        6.00  16.50
# Ph.D.                  4.75   7.75
# Gender               Female  Male
# Education
# Bachelor's Degree        70    50
# High School or Less      42    98
# Master's Degree          24    66
# Ph.D.                    19    31

# %%
filtered_df = df[df['S_Problems'] != 'None']

grouped = filtered_df.groupby(['Education', 'Gender']).size().unstack(fill_value=0)

total_users = grouped.sum().sum()

percentage_grouped = (grouped / total_users) * 100

percentage_grouped = percentage_grouped.T

percentage_grouped = percentage_grouped[percentage_grouped.sum().sort_values(ascending=False).index]

ax = percentage_grouped.plot(kind='bar', figsize=(12, 8), width=0.8, cmap='Set3')

print(tabulate(percentage_grouped, headers='keys', tablefmt='grid'))

plt.xlabel('Gender', fontweight='bold', fontsize=15)
plt.ylabel('Percentage of Users Facing Problems', fontweight='bold', fontsize=15)
plt.legend(title='Education Level', loc='upper right')
plt.xticks(rotation=0)

for i, col in enumerate(percentage_grouped.columns):
    for j, value in enumerate(percentage_grouped[col]):
        if value > 0:
            x = ax.patches[i * len(percentage_grouped[col]) + j].get_x() + ax.patches[i * len(percentage_grouped[col]) + j].get_width() / 2
            height = ax.patches[i * len(percentage_grouped[col]) + j].get_height()
            plt.annotate(f'{value:.2f}%', (x, height), ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

plt.show()
# Out:
# +----------+-----------------------+---------------------+-------------------+---------+
# | Gender   |   High School or Less |   Bachelor's Degree |   Master's Degree |   Ph.D. |
# +==========+=======================+=====================+===================+=========+
# | Female   |                  10.5 |                17.5 |               6   |    4.75 |
# +----------+-----------------------+---------------------+-------------------+---------+
# | Male     |                  24.5 |                12.5 |              16.5 |    7.75 |
# +----------+-----------------------+---------------------+-------------------+---------+

# %%
filtered_identity_theft_df = df[(df['AOYA'] == 'Yes') & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_hacking_df = df[(df['AOYA'] == 'Yes') & (df['S_Problems'].str.contains('Hacking'))]

num_users_with_identity_theft = len(filtered_identity_theft_df)
num_users_with_hacking = len(filtered_hacking_df)

total_users = len(df)
percentage_identity_theft = (num_users_with_identity_theft / total_users) * 100
percentage_hacking = (num_users_with_hacking / total_users) * 100

plt.figure(figsize=(6, 10))
categories = ['"Yes" in AOYA faced "Identity Theft"', '"Yes" in AOYA faced "Hacking"']
counts = [num_users_with_identity_theft, num_users_with_hacking]
percentages = [percentage_identity_theft, percentage_hacking]

table = {
    'Category': ['"Yes" in AOYA faced "Identity Theft"', '"Yes" in AOYA faced "Hacking"'],
    'Count': counts,
    'Percentage': [f'{percentage:.2f}%' for percentage in percentages]
}

print(tabulate(table, headers='keys', tablefmt='grid'))

plt.bar(categories, counts, color=['skyblue', 'lightgreen'], width=0.2)
plt.xlabel('Category')
plt.ylabel('Count')
for i, (count, percentage) in enumerate(zip(counts, percentages)):
    plt.text(i, count, f'{count}\n{percentage:.2f}%', ha='center', va='bottom', fontsize=10, color='black')
plt.show()
# Out:
# +--------------------------------------+---------+--------------+
# | Category                             |   Count | Percentage   |
# +======================================+=========+==============+
# | "Yes" in AOYA faced "Identity Theft" |      84 | 21.00%       |
# +--------------------------------------+---------+--------------+
# | "Yes" in AOYA faced "Hacking"        |     114 | 28.50%       |
# +--------------------------------------+---------+--------------+

# %%
filtered_identity_theft_df = df[(df['AOYA'] == 'Yes') & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_hacking_df = df[(df['AOYA'] == 'Yes') & (df['S_Problems'].str.contains('Hacking'))]

identity_theft_gender_counts = filtered_identity_theft_df['Gender'].value_counts()
hacking_gender_counts = filtered_hacking_df['Gender'].value_counts()

gender_counts_df = pd.DataFrame({
    'Identity Theft': identity_theft_gender_counts,
    'Hacking': hacking_gender_counts
}).fillna(0)

total_users = len(df)
percentage_identity_theft = (identity_theft_gender_counts / total_users) * 100
percentage_hacking = (hacking_gender_counts / total_users) * 100

plt.figure(figsize=(10, 10))

bar_width = 0.35
index = range(len(gender_counts_df))

table = {
    'Gender': gender_counts_df.index,
    'Identity Theft Count': gender_counts_df['Identity Theft'],
    'Identity Theft Percentage': [f'{percentage:.2f}%' for percentage in percentage_identity_theft],
    'Hacking Count': gender_counts_df['Hacking'],
    'Hacking Percentage': [f'{percentage:.2f}%' for percentage in percentage_hacking]
}

print(tabulate(table, headers='keys', tablefmt='grid'))

plt.bar([i - bar_width / 2 for i in index], gender_counts_df['Identity Theft'], width=bar_width, label='Identity Theft', color='skyblue')
plt.bar([i + bar_width / 2 for i in index], gender_counts_df['Hacking'], width=bar_width, label='Hacking', color='lightgreen')

plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(index, gender_counts_df.index)
plt.legend()
for i, (identity_theft_count, hacking_count, percentage_identity_theft, percentage_hacking) in enumerate(zip(
        gender_counts_df['Identity Theft'], gender_counts_df['Hacking'], percentage_identity_theft, percentage_hacking)):
    plt.text(i - bar_width / 2, identity_theft_count, f'{identity_theft_count}\n{percentage_identity_theft:.2f}%', ha='center', va='bottom', fontsize=10, color='black')
    plt.text(i + bar_width / 2, hacking_count, f'{hacking_count}\n{percentage_hacking:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

plt.show()
# Out:
# +----------+------------------------+-----------------------------+-----------------+----------------------+
# | Gender   |   Identity Theft Count | Identity Theft Percentage   |   Hacking Count | Hacking Percentage   |
# +==========+========================+=============================+=================+======================+
# | Female   |                     41 | 10.75%                      |              62 | 15.50%               |
# +----------+------------------------+-----------------------------+-----------------+----------------------+
# | Male     |                     43 | 10.25%                      |              52 | 13.00%               |
# +----------+------------------------+-----------------------------+-----------------+----------------------+

# %%
filtered_df_scam_no = df[(df['a_Scams'] == 'No') & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes = df[(df['a_Scams'] == 'Yes') & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud = df[(df['a_Fraud'] == 'No') & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes = df[(df['a_Fraud'] == 'Yes') & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT = df[(df['a_Identity_Theft'] == 'No') & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes = df[(df['a_Identity_Theft'] == 'Yes') & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p = df[(df['a_Phishing'] == 'No') & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes = df[(df['a_Phishing'] == 'Yes') & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h = df[(df['a_Hacking'] == 'No') & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes = df[(df['a_Hacking'] == 'Yes') & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam = len(filtered_df_scam_no)
num_users_Yes_scam_with_scam = len(filtered_df_scam_Yes)

num_users_no_fraud_with_fraud = len(filtered_df_fraud)
num_users_Yes_fraud_with_fraud = len(filtered_df_scam_Yes)

num_users_no_IDT_with_IDT = len(filtered_df_IDT)
num_users_Yes_IDT_with_IDT = len(filtered_df_IDT_Yes)

num_users_no_p_with_p = len(filtered_df_p)
num_users_Yes_p_with_p = len(filtered_df_p_Yes)

num_users_no_h_with_h = len(filtered_df_h)
num_users_Yes_h_with_h = len(filtered_df_h_Yes)

print(f'Number of users who said "No" in a_Scams and faced "Scam": {num_users_no_scam_with_scam}')
print(f'Number of users who said "Yes" in a_Scams and faced "Scam": {num_users_Yes_scam_with_scam}')

print(f'Number of users who said "No" in a_Fraud and faced "Fraud": {num_users_no_fraud_with_fraud}')
print(f'Number of users who said "Yes" in a_Fraud and faced "Fraud": {num_users_Yes_fraud_with_fraud}')

print(f'Number of users who said "No" in a_Identity_Theft and faced "Identity Theft": {num_users_no_IDT_with_IDT}')
print(f'Number of users who said "Yes" in a_Identity_Theft and faced "Identity Theft": {num_users_Yes_IDT_with_IDT}')

print(f'Number of users who said "No" in a_Phishing and faced "Phishing": {num_users_no_p_with_p}')
print(f'Number of users who said "Yes" in a_Phishing and faced "Phishing": {num_users_Yes_p_with_p}')

print(f'Number of users who said "No" in a_Hacking and faced "Hacking": {num_users_no_h_with_h}')
print(f'Number of users who said "Yes" in a_Hacking and faced "Hacking": {num_users_Yes_h_with_h}')
# Out:
# Number of users who said "No" in a_Scams and faced "Scam": 248
# Number of users who said "Yes" in a_Scams and faced "Scam": 4
# Number of users who said "No" in a_Fraud and faced "Fraud": 176
# Number of users who said "Yes" in a_Fraud and faced "Fraud": 4
# Number of users who said "No" in a_Identity_Theft and faced "Identity Theft": 197
# Number of users who said "Yes" in a_Identity_Theft and faced "Identity Theft": 0
# Number of users who said "No" in a_Phishing and faced "Phishing": 243
# Number of users who said "Yes" in a_Phishing and faced "Phishing": 0
# Number of users who said "No" in a_Hacking and faced "Hacking": 152
# Number of users who said "Yes" in a_Hacking and faced "Hacking": 56

# %%
total_users = len(df)

percentage_no_scam_with_scam = (num_users_no_scam_with_scam / total_users) * 100
percentage_yes_scam_with_scam = (num_users_Yes_scam_with_scam / total_users) * 100

percentage_no_fraud_with_fraud = (num_users_no_fraud_with_fraud / total_users) * 100
percentage_yes_fraud_with_fraud = (num_users_Yes_fraud_with_fraud / total_users) * 100

percentage_no_IDT_with_IDT = (num_users_no_IDT_with_IDT / total_users) * 100
percentage_yes_IDT_with_IDT = (num_users_Yes_IDT_with_IDT / total_users) * 100

percentage_no_p_with_p = (num_users_no_p_with_p / total_users) * 100
percentage_yes_p_with_p = (num_users_Yes_p_with_p / total_users) * 100

percentage_no_h_with_h = (num_users_no_h_with_h / total_users) * 100
percentage_yes_h_with_h = (num_users_Yes_h_with_h / total_users) * 100

table_scam = [
    ["Category", "Count", "Percentage"],
    ["No in a_Scams and faced Scam", num_users_no_scam_with_scam, f"{percentage_no_scam_with_scam:.2f}%"],
    ["Yes in a_Scams and faced Scam", num_users_Yes_scam_with_scam, f"{percentage_yes_scam_with_scam:.2f}%"]
]

table_fraud = [
    ["Category", "Count", "Percentage"],
    ["No in a_Fraud and faced Fraud", num_users_no_fraud_with_fraud, f"{percentage_no_fraud_with_fraud:.2f}%"],
    ["Yes in a_Fraud and faced Fraud", num_users_Yes_fraud_with_fraud, f"{percentage_yes_fraud_with_fraud:.2f}%"]
]

table_IDT = [
    ["Category", "Count", "Percentage"],
    ["No in a_Identity_Theft and faced Identity Theft", num_users_no_IDT_with_IDT, f"{percentage_no_IDT_with_IDT:.2f}%"],
    ["Yes in a_Identity_Theft and faced Identity Theft", num_users_Yes_IDT_with_IDT, f"{percentage_yes_IDT_with_IDT:.2f}%"]
]

table_p = [
    ["Category", "Count", "Percentage"],
    ["No in a_Phishing and faced Phishing", num_users_no_p_with_p, f"{percentage_no_p_with_p:.2f}%"],
    ["Yes in a_Phishing and faced Phishing", num_users_Yes_p_with_p, f"{percentage_yes_p_with_p:.2f}%"]
]

table_h = [
    ["Category", "Count", "Percentage"],
    ["No in a_Hacking and faced Hacking", num_users_no_h_with_h, f"{percentage_no_h_with_h:.2f}%"],
    ["Yes in a_Hacking and faced Hacking", num_users_Yes_h_with_h, f"{percentage_yes_h_with_h:.2f}%"]
]

print("Table for Scam:")
print(tabulate(table_scam, headers="firstrow", tablefmt="grid"))
print("\nTable for Fraud:")
print(tabulate(table_fraud, headers="firstrow", tablefmt="grid"))
print("\nTable for Identity Theft:")
print(tabulate(table_IDT, headers="firstrow", tablefmt="grid"))
print("\nTable for Phishing:")
print(tabulate(table_p, headers="firstrow", tablefmt="grid"))
print("\nTable for Hacking:")
print(tabulate(table_h, headers="firstrow", tablefmt="grid"))
# Out:
# Table for Scam:
# +-------------------------------+---------+--------------+
# | Category                      |   Count | Percentage   |
# +===============================+=========+==============+
# | No in a_Scams and faced Scam  |     248 | 62.00%       |
# +-------------------------------+---------+--------------+
# | Yes in a_Scams and faced Scam |       4 | 1.00%        |
# +-------------------------------+---------+--------------+
#
# Table for Fraud:
# +--------------------------------+---------+--------------+
# | Category                       |   Count | Percentage   |
# +================================+=========+==============+
# | No in a_Fraud and faced Fraud  |     176 | 44.00%       |
# +--------------------------------+---------+--------------+
# | Yes in a_Fraud and faced Fraud |       4 | 1.00%        |
# +--------------------------------+---------+--------------+
#
# Table for Identity Theft:
# ...

# %%
total_users = len(df)

categories = ['Not Aware of Scam', 'Aware of Scam']
counts = [
    num_users_no_scam_with_scam,
    num_users_Yes_scam_with_scam,
]
percentages = [count / total_users * 100 for count in counts]

plt.figure(figsize=(15, 10))
plt.plot(categories, counts, marker='o', linestyle='-', color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Victim of Scam')
plt.grid(True)

for i, (count, percentage) in enumerate(zip(counts, percentages)):
    plt.text(categories[i], count, f'{count}\n{percentage:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
total_users = len(df)

categories = ['Not Aware of Fraud', 'Aware of Fraud']
counts = [
  num_users_no_fraud_with_fraud,
  num_users_Yes_fraud_with_fraud
]
percentages = [count / total_users * 100 for count in counts]

plt.figure(figsize=(15, 10))
plt.plot(categories, counts, marker='o', linestyle='-', color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Victim of Fraud count')
plt.grid(True)

for i, (count, percentage) in enumerate(zip(counts, percentages)):
    plt.text(categories[i], count, f'{count}\n{percentage:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
total_users = len(df)

categories = ['Not Aware of Identity Theft', 'Aware of Identity Theft']
counts = [
  num_users_no_IDT_with_IDT,
  num_users_Yes_IDT_with_IDT
]
percentages = [count / total_users * 100 for count in counts]

plt.figure(figsize=(15, 10))
plt.plot(categories, counts, marker='o', linestyle='-', color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Victim of Identity Theft count')
plt.grid(True)

for i, (count, percentage) in enumerate(zip(counts, percentages)):
    plt.text(categories[i], count, f'{count}\n{percentage:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
total_users = len(df)

categories = ['Not Aware of Phishing', 'Aware of Phishing']
counts = [
  num_users_no_p_with_p,
  num_users_Yes_p_with_p
]
percentages = [count / total_users * 100 for count in counts]

plt.figure(figsize=(15, 10))
plt.plot(categories, counts, marker='o', linestyle='-', color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Victim of Phishing count')
plt.grid(True)

for i, (count, percentage) in enumerate(zip(counts, percentages)):
    plt.text(categories[i], count, f'{count}\n{percentage:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
total_users = len(df)

categories = ['Not Aware of Hacking', 'Aware of Hacking']
counts = [
  num_users_no_h_with_h,
  num_users_Yes_h_with_h
]
percentages = [count / total_users * 100 for count in counts]

plt.figure(figsize=(15, 10))
plt.plot(categories, counts, marker='o', linestyle='-', color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Victim of Hacking count')
plt.grid(True)

for i, (count, percentage) in enumerate(zip(counts, percentages)):
    plt.text(categories[i], count, f'{count}\n{percentage:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
filtered_df_scam = df[(df['a_Scams'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes = df[(df['a_Scams'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud = df[(df['a_Fraud'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes = df[(df['a_Fraud'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT = df[(df['a_Identity_Theft'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes = df[(df['a_Identity_Theft'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p = df[(df['a_Phishing'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes = df[(df['a_Phishing'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h = df[(df['a_Hacking'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes = df[(df['a_Hacking'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam = len(filtered_df_scam)
num_users_Yes_scam_with_scam = len(filtered_df_scam_Yes)

num_users_no_fraud_with_fraud = len(filtered_df_fraud)
num_users_Yes_fraud_with_fraud = len(filtered_df_fraud_Yes)

num_users_no_IDT_with_IDT = len(filtered_df_IDT)
num_users_Yes_IDT_with_IDT = len(filtered_df_IDT_Yes)

num_users_no_p_with_p = len(filtered_df_p)
num_users_Yes_p_with_p = len(filtered_df_p_Yes)

num_users_no_h_with_h = len(filtered_df_h)
num_users_Yes_h_with_h = len(filtered_df_h_Yes)

print(f'Number of users who said "No" in a_Scam use bKash and faced "Scam": {num_users_no_scam_with_scam}')
print(f'Number of users who said "Yes" in a_Scam use bKash and faced "Scam": {num_users_Yes_scam_with_scam}\n')

print(f'Number of users who said "No" in a_Fraud use bKash and faced "Fraud": {num_users_no_fraud_with_fraud}')
print(f'Number of users who said "Yes" in a_Fraud use bKash and faced "Fraud": {num_users_Yes_fraud_with_fraud}\n')

print(f'Number of users who said "No" in a_Identity_Theft use bKash and faced "Identity Theft": {num_users_no_IDT_with_IDT}')
print(f'Number of users who said "Yes" in a_Identity_Theft use bKash and faced "Identity Theft": {num_users_Yes_IDT_with_IDT}\n')

print(f'Number of users who said "No" in a_Phishing use bKash and faced "Phishing": {num_users_no_p_with_p}')
print(f'Number of users who said "Yes" in a_Phishing use bKash and faced "Phishing": {num_users_Yes_p_with_p}\n')

print(f'Number of users who said "No" in a_Hacking use bKash and faced "Hacking": {num_users_no_h_with_h}')
print(f'Number of users who said "Yes" in a_Hacking use bKash and faced "Hacking": {num_users_Yes_h_with_h}')
# Out:
# Number of users who said "No" in a_Scam use bKash and faced "Scam": 178
# Number of users who said "Yes" in a_Scam use bKash and faced "Scam": 4
#
# Number of users who said "No" in a_Fraud use bKash and faced "Fraud": 117
# Number of users who said "Yes" in a_Fraud use bKash and faced "Fraud": 0
#
# Number of users who said "No" in a_Identity_Theft use bKash and faced "Identity Theft": 133
# Number of users who said "Yes" in a_Identity_Theft use bKash and faced "Identity Theft": 0
#
# Number of users who said "No" in a_Phishing use bKash and faced "Phishing": 173
# Number of users who said "Yes" in a_Phishing use bKash and faced "Phishing": 0
#
# Number of users who said "No" in a_Hacking use bKash and faced "Hacking": 117
# Number of users who said "Yes" in a_Hacking use bKash and faced "Hacking": 51

# %%
filtered_df_scam = df[(df['a_Scams'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes = df[(df['a_Scams'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud = df[(df['a_Fraud'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes = df[(df['a_Fraud'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT = df[(df['a_Identity_Theft'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes = df[(df['a_Identity_Theft'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p = df[(df['a_Phishing'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes = df[(df['a_Phishing'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h = df[(df['a_Hacking'] == 'No') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes = df[(df['a_Hacking'] == 'Yes') & (df['MBS'].str.contains('bKash')) & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam = len(filtered_df_scam)
num_users_Yes_scam_with_scam = len(filtered_df_scam_Yes)

num_users_no_fraud_with_fraud = len(filtered_df_fraud)
num_users_Yes_fraud_with_fraud = len(filtered_df_fraud_Yes)

num_users_no_IDT_with_IDT = len(filtered_df_IDT)
num_users_Yes_IDT_with_IDT = len(filtered_df_IDT_Yes)

num_users_no_p_with_p = len(filtered_df_p)
num_users_Yes_p_with_p = len(filtered_df_p_Yes)

num_users_no_h_with_h = len(filtered_df_h)
num_users_Yes_h_with_h = len(filtered_df_h_Yes)

total_users_scam = num_users_no_scam_with_scam + num_users_Yes_scam_with_scam
total_users_fraud = num_users_no_fraud_with_fraud + num_users_Yes_fraud_with_fraud
total_users_IDT = num_users_no_IDT_with_IDT + num_users_Yes_IDT_with_IDT
total_users_p = num_users_no_p_with_p + num_users_Yes_p_with_p
total_users_h = num_users_no_h_with_h + num_users_Yes_h_with_h

percentage_no_scam_with_scam = (num_users_no_scam_with_scam / total_users_scam) * 100
percentage_Yes_scam_with_scam = (num_users_Yes_scam_with_scam / total_users_scam) * 100

percentage_no_fraud_with_fraud = (num_users_no_fraud_with_fraud / total_users_fraud) * 100
percentage_Yes_fraud_with_fraud = (num_users_Yes_fraud_with_fraud / total_users_fraud) * 100

percentage_no_IDT_with_IDT = (num_users_no_IDT_with_IDT / total_users_IDT) * 100
percentage_Yes_IDT_with_IDT = (num_users_Yes_IDT_with_IDT / total_users_IDT) * 100

percentage_no_p_with_p = (num_users_no_p_with_p / total_users_p) * 100
percentage_Yes_p_with_p = (num_users_Yes_p_with_p / total_users_p) * 100

percentage_no_h_with_h = (num_users_no_h_with_h / total_users_h) * 100
percentage_Yes_h_with_h = (num_users_Yes_h_with_h / total_users_h) * 100

data = {
    'Security Issue': ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking'],
    'Count (No)': [num_users_no_scam_with_scam, num_users_no_fraud_with_fraud, num_users_no_IDT_with_IDT, num_users_no_p_with_p, num_users_no_h_with_h],
    'Percentage (No)': [percentage_no_scam_with_scam, percentage_no_fraud_with_fraud, percentage_no_IDT_with_IDT, percentage_no_p_with_p, percentage_no_h_with_h],
    'Count (Yes)': [num_users_Yes_scam_with_scam, num_users_Yes_fraud_with_fraud, num_users_Yes_IDT_with_IDT, num_users_Yes_p_with_p, num_users_Yes_h_with_h],
    'Percentage (Yes)': [percentage_Yes_scam_with_scam, percentage_Yes_fraud_with_fraud, percentage_Yes_IDT_with_IDT, percentage_Yes_p_with_p, percentage_Yes_h_with_h]
}

df_results = pd.DataFrame(data)

print(tabulate(df_results, headers='keys', tablefmt='grid'))
# Out:
# +----+------------------+--------------+-------------------+---------------+--------------------+
# |    | Security Issue   |   Count (No) |   Percentage (No) |   Count (Yes) |   Percentage (Yes) |
# +====+==================+==============+===================+===============+====================+
# |  0 | Scam             |          178 |           97.8022 |             4 |             2.1978 |
# +----+------------------+--------------+-------------------+---------------+--------------------+
# |  1 | Fraud            |          117 |          100      |             0 |             0      |
# +----+------------------+--------------+-------------------+---------------+--------------------+
# |  2 | Identity Theft   |          133 |          100      |             0 |             0      |
# +----+------------------+--------------+-------------------+---------------+--------------------+
# |  3 | Phishing         |          173 |          100      |             0 |             0      |
# ...

# %%
categories = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
no_counts = [
    num_users_no_scam_with_scam,
    num_users_no_fraud_with_fraud,
    num_users_no_IDT_with_IDT,
    num_users_no_p_with_p,
    num_users_no_h_with_h
]
yes_counts = [
    num_users_Yes_scam_with_scam,
    num_users_Yes_fraud_with_fraud,
    num_users_Yes_IDT_with_IDT,
    num_users_Yes_p_with_p,
    num_users_Yes_h_with_h
]

total_counts = [n1 + n2 for n1, n2 in zip(no_counts, yes_counts)]
no_percentages = [n1 / total * 100 for n1, total in zip(no_counts, total_counts)]
yes_percentages = [n2 / total * 100 for n2, total in zip(yes_counts, total_counts)]

bar_width = 0.35

x = range(len(categories))

data = {
    'Problem Type': categories,
    'Count (No)': no_counts,
    'Percentage (No)': no_percentages,
    'Count (Yes)': yes_counts,
    'Percentage (Yes)': yes_percentages
}

df_table = pd.DataFrame(data)

df_table.set_index('Problem Type', inplace=True)

print(df_table)

fig, ax = plt.subplots(figsize=(15, 8))

bar1 = ax.bar(x, no_counts, bar_width, label='No')
bar2 = ax.bar([i + bar_width for i in x], yes_counts, bar_width, label='Yes')

ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(categories)

for i, (n1, n2) in enumerate(zip(no_counts, yes_counts)):
    ax.text(i - bar_width / 2, max(n1, n2) + 5, f'{n1}', ha='center', va='bottom')

ax.set_xlabel('Problem Type')
ax.set_ylabel('bKash Users')
ax.legend()

ax2 = ax.twinx()
ax2.set_ylabel('Percentage')
ax2.set_ylim(0, 100)
for i, v in enumerate(no_percentages):
    ax2.text(i - bar_width / 2, v + 5, f'{v:.2f}%', ha='center', va='top', color='blue')
for i, v in enumerate(yes_percentages):
    ax2.text(i + bar_width * 1.5, v + 5, f'{v:.2f}%', ha='center', va='top', color='orange')

plt.tight_layout()
plt.show()
# Out:
#                 Count (No)  Percentage (No)  Count (Yes)  Percentage (Yes)
# Problem Type
# Scam                   178        97.802198            4          2.197802
# Fraud                  117       100.000000            0          0.000000
# Identity Theft         133       100.000000            0          0.000000
# Phishing               173       100.000000            0          0.000000
# Hacking                117        69.642857           51         30.357143

# %%
filtered_df_scam_nagad = df[(df['a_Scams'] == 'No') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes_nagad = df[(df['a_Scams'] == 'Yes') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud_nagad = df[(df['a_Fraud'] == 'No') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes_nagad = df[(df['a_Fraud'] == 'Yes') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT_nagad = df[(df['a_Identity_Theft'] == 'No') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes_nagad = df[(df['a_Identity_Theft'] == 'Yes') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p_nagad = df[(df['a_Phishing'] == 'No') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes_nagad = df[(df['a_Phishing'] == 'Yes') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h_nagad = df[(df['a_Hacking'] == 'No') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes_nagad = df[(df['a_Hacking'] == 'Yes') & (df['MBS'].str.contains('Nagad')) & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam_nagad = len(filtered_df_scam_nagad)
num_users_Yes_scam_with_scam_nagad = len(filtered_df_scam_Yes_nagad)

num_users_no_fraud_with_fraud_nagad = len(filtered_df_fraud_nagad)
num_users_Yes_fraud_with_fraud_nagad = len(filtered_df_fraud_Yes_nagad)

num_users_no_IDT_with_IDT_nagad = len(filtered_df_IDT_nagad)
num_users_Yes_IDT_with_IDT_nagad = len(filtered_df_IDT_Yes_nagad)

num_users_no_p_with_p_nagad = len(filtered_df_p_nagad)
num_users_Yes_p_with_p_nagad = len(filtered_df_p_Yes_nagad)

num_users_no_h_with_h_nagad = len(filtered_df_h_nagad)
num_users_Yes_h_with_h_nagad = len(filtered_df_h_Yes_nagad)

print(f'Number of users who said "No" in a_Scam use Nagad and faced "Scam": {num_users_no_scam_with_scam_nagad}')
print(f'Number of users who said "Yes" in a_Scam use Nagad and faced "Scam": {num_users_Yes_scam_with_scam_nagad}\n')

print(f'Number of users who said "No" in a_Fraud use Nagad and faced "Fraud": {num_users_no_fraud_with_fraud_nagad}')
print(f'Number of users who said "Yes" in a_Fraud use Nagad and faced "Fraud": {num_users_Yes_fraud_with_fraud_nagad}\n')

print(f'Number of users who said "No" in a_Identity_Theft use Nagad and faced "Identity Theft": {num_users_no_IDT_with_IDT_nagad}')
print(f'Number of users who said "Yes" in a_Identity_Theft use Nagad and faced "Identity Theft": {num_users_Yes_IDT_with_IDT_nagad}\n')

print(f'Number of users who said "No" in a_Phishing use Nagad and faced "Phishing": {num_users_no_p_with_p_nagad}')
print(f'Number of users who said "Yes" in a_Phishing use Nagad and faced "Phishing": {num_users_Yes_p_with_p_nagad}\n')

print(f'Number of users who said "No" in a_Hacking use Nagad and faced "Hacking": {num_users_no_h_with_h_nagad}')
print(f'Number of users who said "Yes" in a_Hacking use Nagad and faced "Hacking": {num_users_Yes_h_with_h_nagad}')
# Out:
# Number of users who said "No" in a_Scam use Nagad and faced "Scam": 26
# Number of users who said "Yes" in a_Scam use Nagad and faced "Scam": 0
#
# Number of users who said "No" in a_Fraud use Nagad and faced "Fraud": 23
# Number of users who said "Yes" in a_Fraud use Nagad and faced "Fraud": 0
#
# Number of users who said "No" in a_Identity_Theft use Nagad and faced "Identity Theft": 25
# Number of users who said "Yes" in a_Identity_Theft use Nagad and faced "Identity Theft": 0
#
# Number of users who said "No" in a_Phishing use Nagad and faced "Phishing": 26
# Number of users who said "Yes" in a_Phishing use Nagad and faced "Phishing": 0
#
# Number of users who said "No" in a_Hacking use Nagad and faced "Hacking": 8
# Number of users who said "Yes" in a_Hacking use Nagad and faced "Hacking": 0

# %%
categories_nagad = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
no_counts_nagad = [
    num_users_no_scam_with_scam_nagad,
    num_users_no_fraud_with_fraud_nagad,
    num_users_no_IDT_with_IDT_nagad,
    num_users_no_p_with_p_nagad,
    num_users_no_h_with_h_nagad
]
yes_counts_nagad = [
    num_users_Yes_scam_with_scam_nagad,
    num_users_Yes_fraud_with_fraud_nagad,
    num_users_Yes_IDT_with_IDT_nagad,
    num_users_Yes_p_with_p_nagad,
    num_users_Yes_h_with_h_nagad
]

total_counts_nagad = [n1 + n2 for n1, n2 in zip(no_counts_nagad, yes_counts_nagad)]

no_percentages = [(n1 / total) * 100 for n1, total in zip(no_counts_nagad, total_counts_nagad)]
yes_percentages = [(n2 / total) * 100 for n2, total in zip(yes_counts_nagad, total_counts_nagad)]

data = {
    'Problem Type': categories_nagad,
    'Count (No)': no_counts_nagad,
    'Percentage (No)': no_percentages,
    'Count (Yes)': yes_counts_nagad,
    'Percentage (Yes)': yes_percentages
}
df_nagad = pd.DataFrame(data)

print(df_nagad)

bar_width = 0.35
x = range(len(categories_nagad))

fig, ax = plt.subplots(figsize=(15, 8))

bar1 = ax.bar(x, no_counts_nagad, bar_width, label='No')
bar2 = ax.bar([i + bar_width for i in x], yes_counts_nagad, bar_width, label='Yes')

ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(categories_nagad)

for i, (n1, n2) in enumerate(zip(no_counts_nagad, yes_counts_nagad)):
    ax.text(i - bar_width / 2, max(n1, n2) + 5, f'{n1}', ha='center', va='bottom')

ax.set_xlabel('Problem Type')
ax.set_ylabel('Nagad Users')
ax.legend()

ax2 = ax.twinx()
ax2.set_ylabel('Percentage')
ax2.set_ylim(0, 100)
for i, v in enumerate(no_percentages):
    ax2.text(i - bar_width / 2, v + 5, f'{v:.2f}%', ha='center', va='top', color='blue')
for i, v in enumerate(yes_percentages):
    ax2.text(i + bar_width * 1.5, v + 5, f'{v:.2f}%', ha='center', va='top', color='orange')

plt.tight_layout()
plt.show()
# Out:
#      Problem Type  Count (No)  Percentage (No)  Count (Yes)  Percentage (Yes)
# 0            Scam          26            100.0            0               0.0
# 1           Fraud          23            100.0            0               0.0
# 2  Identity Theft          25            100.0            0               0.0
# 3        Phishing          26            100.0            0               0.0
# 4         Hacking           8            100.0            0               0.0

# %%
filtered_df_scam_rocket = df[(df['a_Scams'] == 'No') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes_rocket = df[(df['a_Scams'] == 'Yes') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud_rocket = df[(df['a_Fraud'] == 'No') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes_rocket = df[(df['a_Fraud'] == 'Yes') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT_rocket = df[(df['a_Identity_Theft'] == 'No') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes_rocket = df[(df['a_Identity_Theft'] == 'Yes') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p_rocket = df[(df['a_Phishing'] == 'No') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes_rocket = df[(df['a_Phishing'] == 'Yes') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h_rocket = df[(df['a_Hacking'] == 'No') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes_rocket = df[(df['a_Hacking'] == 'Yes') & (df['MBS'].str.contains('Rocket')) & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam_rocket = len(filtered_df_scam_rocket)
num_users_Yes_scam_with_scam_rocket = len(filtered_df_scam_Yes_rocket)

num_users_no_fraud_with_fraud_rocket = len(filtered_df_fraud_rocket)
num_users_Yes_fraud_with_fraud_rocket = len(filtered_df_fraud_Yes_rocket)

num_users_no_IDT_with_IDT_rocket = len(filtered_df_IDT_rocket)
num_users_Yes_IDT_with_IDT_rocket = len(filtered_df_IDT_Yes_rocket)

num_users_no_p_with_p_rocket = len(filtered_df_p_rocket)
num_users_Yes_p_with_p_rocket = len(filtered_df_p_Yes_rocket)

num_users_no_h_with_h_rocket = len(filtered_df_h_rocket)
num_users_Yes_h_with_h_rocket = len(filtered_df_h_Yes_rocket)


print(f'Number of users who said "No" in a_Scam use Rocket and faced "Scam": {num_users_no_scam_with_scam_rocket}')
print(f'Number of users who said "Yes" in a_Scam use Rocket and faced "Scam": {num_users_Yes_scam_with_scam_rocket}\n')

print(f'Number of users who said "No" in a_Fraud use Rocket and faced "Fraud": {num_users_no_fraud_with_fraud_rocket}')
print(f'Number of users who said "Yes" in a_Fraud use Rocket and faced "Fraud": {num_users_Yes_fraud_with_fraud_rocket}\n')

print(f'Number of users who said "No" in a_Identity_Theft use Rocket and faced "Identity Theft": {num_users_no_IDT_with_IDT_rocket}')
print(f'Number of users who said "Yes" in a_Identity_Theft use Rocket and faced "Identity Theft": {num_users_Yes_IDT_with_IDT_rocket}\n')

print(f'Number of users who said "No" in a_Phishing use Rocket and faced "Phishing": {num_users_no_p_with_p_rocket}')
print(f'Number of users who said "Yes" in a_Phishing use Rocket and faced "Phishing": {num_users_Yes_p_with_p_rocket}\n')

print(f'Number of users who said "No" in a_Hacking use Rocket and faced "Hacking": {num_users_no_h_with_h_rocket}')
print(f'Number of users who said "Yes" in a_Hacking use Rocket and faced "Hacking": {num_users_Yes_h_with_h_rocket}')
# Out:
# Number of users who said "No" in a_Scam use Rocket and faced "Scam": 149
# Number of users who said "Yes" in a_Scam use Rocket and faced "Scam": 0
#
# Number of users who said "No" in a_Fraud use Rocket and faced "Fraud": 105
# Number of users who said "Yes" in a_Fraud use Rocket and faced "Fraud": 0
#
# Number of users who said "No" in a_Identity_Theft use Rocket and faced "Identity Theft": 121
# Number of users who said "Yes" in a_Identity_Theft use Rocket and faced "Identity Theft": 0
#
# Number of users who said "No" in a_Phishing use Rocket and faced "Phishing": 149
# Number of users who said "Yes" in a_Phishing use Rocket and faced "Phishing": 0
#
# Number of users who said "No" in a_Hacking use Rocket and faced "Hacking": 101
# Number of users who said "Yes" in a_Hacking use Rocket and faced "Hacking": 26

# %%
categories_rocket = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
no_counts_rocket = [
    num_users_no_scam_with_scam_rocket,
    num_users_no_fraud_with_fraud_rocket,
    num_users_no_IDT_with_IDT_rocket,
    num_users_no_p_with_p_rocket,
    num_users_no_h_with_h_rocket
]
yes_counts_rocket = [
    num_users_Yes_scam_with_scam_rocket,
    num_users_Yes_fraud_with_fraud_rocket,
    num_users_Yes_IDT_with_IDT_rocket,
    num_users_Yes_p_with_p_rocket,
    num_users_Yes_h_with_h_rocket
]

total_counts_rocket = [n1 + n2 for n1, n2 in zip(no_counts_rocket, yes_counts_rocket)]
no_percentages = [n1 / total * 100 for n1, total in zip(no_counts_rocket, total_counts_rocket)]
yes_percentages = [n2 / total * 100 for n2, total in zip(yes_counts_rocket, total_counts_rocket)]

bar_width = 0.35

x = range(len(categories_rocket))

fig, ax = plt.subplots(figsize=(15, 8))

bar1 = ax.bar(x, no_counts_rocket, bar_width, label='No')
bar2 = ax.bar([i + bar_width for i in x], yes_counts_rocket, bar_width, label='Yes')

ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(categories_rocket)

for i, (n1, n2) in enumerate(zip(no_counts_rocket, yes_counts_rocket)):
    ax.text(i - bar_width / 2, max(n1, n2) + 5, f'{n1}', ha='center', va='bottom')

ax.set_xlabel('Problem Type')
ax.set_ylabel('Rocket Users')
ax.legend()

ax2 = ax.twinx()
ax2.set_ylabel('Percentage')
ax2.set_ylim(0, 100)
for i, v in enumerate(no_percentages):
    ax2.text(i - bar_width / 2, v + 5, f'{v:.2f}%', ha='center', va='top', color='blue')
for i, v in enumerate(yes_percentages):
    ax2.text(i + bar_width * 1.5, v + 5, f'{v:.2f}%', ha='center', va='top', color='orange')

data_rocket = {
    'Problem Type': categories_rocket,
    'Count (No)': no_counts_rocket,
    'Percentage (No)': [100.0] * len(categories_rocket),
    'Count (Yes)': yes_counts_rocket,
    'Percentage (Yes)': yes_percentages
}

df_rocket = pd.DataFrame(data_rocket)

print(df_rocket)

plt.tight_layout()
plt.show()
# Out:
#      Problem Type  Count (No)  Percentage (No)  Count (Yes)  Percentage (Yes)
# 0            Scam         149            100.0            0          0.000000
# 1           Fraud         105            100.0            0          0.000000
# 2  Identity Theft         121            100.0            0          0.000000
# 3        Phishing         149            100.0            0          0.000000
# 4         Hacking         101            100.0           26         20.472441

# %%
filtered_df_scam_sc = df[(df['a_Scams'] == 'No') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes_sc = df[(df['a_Scams'] == 'Yes') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud_sc = df[(df['a_Fraud'] == 'No') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes_sc = df[(df['a_Fraud'] == 'Yes') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT_sc = df[(df['a_Identity_Theft'] == 'No') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes_sc = df[(df['a_Identity_Theft'] == 'Yes') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p_sc = df[(df['a_Phishing'] == 'No') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes_sc = df[(df['a_Phishing'] == 'Yes') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h_sc = df[(df['a_Hacking'] == 'No') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes_sc = df[(df['a_Hacking'] == 'Yes') & (df['MBS'].str.contains('SureCash')) & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam_sc = len(filtered_df_scam_sc)
num_users_Yes_scam_with_scam_sc = len(filtered_df_scam_Yes_sc)

num_users_no_fraud_with_fraud_sc = len(filtered_df_fraud_sc)
num_users_Yes_fraud_with_fraud_sc = len(filtered_df_fraud_Yes_sc)

num_users_no_IDT_with_IDT_sc = len(filtered_df_IDT_sc)
num_users_Yes_IDT_with_IDT_sc = len(filtered_df_IDT_Yes_sc)

num_users_no_p_with_p_sc = len(filtered_df_p_sc)
num_users_Yes_p_with_p_sc = len(filtered_df_p_Yes_sc)

num_users_no_h_with_h_sc = len(filtered_df_h_sc)
num_users_Yes_h_with_h_sc = len(filtered_df_h_Yes_sc)

print(f'Number of users who said "No" in a_Scam use SureCash and faced "Scam": {num_users_no_scam_with_scam_sc}')
print(f'Number of users who said "Yes" in a_Scam use SureCash and faced "Scam": {num_users_Yes_scam_with_scam_sc}\n')

print(f'Number of users who said "No" in a_Fraud use SureCash and faced "Fraud": {num_users_no_fraud_with_fraud_sc}')
print(f'Number of users who said "Yes" in a_Fraud use SureCash and faced "Fraud": {num_users_Yes_fraud_with_fraud_sc}\n')

print(f'Number of users who said "No" in a_Identity_Theft use SureCash and faced "Identity Theft": {num_users_no_IDT_with_IDT_sc}')
print(f'Number of users who said "Yes" in a_Identity_Theft use SureCash and faced "Identity Theft": {num_users_Yes_IDT_with_IDT_sc}\n')

print(f'Number of users who said "No" in a_Phishing use SureCash and faced "Phishing": {num_users_no_p_with_p_sc}')
print(f'Number of users who said "Yes" in a_Phishing use SureCash and faced "Phishing": {num_users_Yes_p_with_p_sc}\n')

print(f'Number of users who said "No" in a_Hacking use SureCash and faced "Hacking": {num_users_no_h_with_h_sc}')
print(f'Number of users who said "Yes" in a_Hacking use SureCash and faced "Hacking": {num_users_Yes_h_with_h_sc}')
# Out:
# Number of users who said "No" in a_Scam use SureCash and faced "Scam": 5
# Number of users who said "Yes" in a_Scam use SureCash and faced "Scam": 0
#
# Number of users who said "No" in a_Fraud use SureCash and faced "Fraud": 5
# Number of users who said "Yes" in a_Fraud use SureCash and faced "Fraud": 0
#
# Number of users who said "No" in a_Identity_Theft use SureCash and faced "Identity Theft": 5
# Number of users who said "Yes" in a_Identity_Theft use SureCash and faced "Identity Theft": 0
#
# Number of users who said "No" in a_Phishing use SureCash and faced "Phishing": 5
# Number of users who said "Yes" in a_Phishing use SureCash and faced "Phishing": 0
#
# Number of users who said "No" in a_Hacking use SureCash and faced "Hacking": 1
# Number of users who said "Yes" in a_Hacking use SureCash and faced "Hacking": 1

# %%
categories_sc = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
no_counts_sc = [
    num_users_no_scam_with_scam_sc,
    num_users_no_fraud_with_fraud_sc,
    num_users_no_IDT_with_IDT_sc,
    num_users_no_p_with_p_sc,
    num_users_no_h_with_h_sc
]
yes_counts_sc = [
    num_users_Yes_scam_with_scam_sc,
    num_users_Yes_fraud_with_fraud_sc,
    num_users_Yes_IDT_with_IDT_sc,
    num_users_Yes_p_with_p_sc,
    num_users_Yes_h_with_h_sc
]

total_counts_sc = [n1 + n2 for n1, n2 in zip(no_counts_sc, yes_counts_sc)]
no_percentages = [n1 / total * 100 for n1, total in zip(no_counts_sc, total_counts_sc)]
yes_percentages = [n2 / total * 100 for n2, total in zip(yes_counts_sc, total_counts_sc)]

bar_width = 0.35

x = range(len(categories_sc))

fig, ax = plt.subplots(figsize=(15, 8))

bar1 = ax.bar(x, no_counts_sc, bar_width, label='No')
bar2 = ax.bar([i + bar_width for i in x], yes_counts_sc, bar_width, label='Yes')

ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(categories_sc)

for i, (n1, n2) in enumerate(zip(no_counts_sc, yes_counts_sc)):
    ax.text(i - bar_width / 2, max(n1, n2) + 5, f'{n1}', ha='center', va='bottom')

ax.set_xlabel('Problem Type')
ax.set_ylabel('SureCash Users')
ax.legend()

ax2 = ax.twinx()
ax2.set_ylabel('Percentage')
ax2.set_ylim(0, 100)
for i, v in enumerate(no_percentages):
    ax2.text(i - bar_width / 2, v + 5, f'{v:.2f}%', ha='center', va='bottom', color='blue')
for i, v in enumerate(yes_percentages):
    ax2.text(i + bar_width * 1.5, v + 5, f'{v:.2f}%', ha='center', va='bottom', color='orange')

data_sc = {
    'Problem Type': categories_sc,
    'Count (No)': no_counts_sc,
    'Percentage (No)': [100.0] * len(categories_sc),
    'Count (Yes)': yes_counts_sc,
    'Percentage (Yes)': yes_percentages
}

df_sc = pd.DataFrame(data_sc)

print(df_sc)

plt.tight_layout()
plt.show()
# Out:
#      Problem Type  Count (No)  Percentage (No)  Count (Yes)  Percentage (Yes)
# 0            Scam           5            100.0            0               0.0
# 1           Fraud           5            100.0            0               0.0
# 2  Identity Theft           5            100.0            0               0.0
# 3        Phishing           5            100.0            0               0.0
# 4         Hacking           1            100.0            1              50.0

# %%
filtered_df_scam_up = df[(df['a_Scams'] == 'No') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes_up = df[(df['a_Scams'] == 'Yes') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud_up = df[(df['a_Fraud'] == 'No') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes_up = df[(df['a_Fraud'] == 'Yes') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT_up = df[(df['a_Identity_Theft'] == 'No') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes_up = df[(df['a_Identity_Theft'] == 'Yes') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p_up = df[(df['a_Phishing'] == 'No') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes_up = df[(df['a_Phishing'] == 'Yes') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h_up = df[(df['a_Hacking'] == 'No') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes_up = df[(df['a_Hacking'] == 'Yes') & (df['MBS'].str.contains('Upay')) & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam_up = len(filtered_df_scam_up)
num_users_Yes_scam_with_scam_up = len(filtered_df_scam_Yes_up)

num_users_no_fraud_with_fraud_up = len(filtered_df_fraud_up)
num_users_Yes_fraud_with_fraud_up = len(filtered_df_fraud_Yes_up)

num_users_no_IDT_with_IDT_up = len(filtered_df_IDT_up)
num_users_Yes_IDT_with_IDT_up = len(filtered_df_IDT_Yes_up)

num_users_no_p_with_p_up = len(filtered_df_p_up)
num_users_Yes_p_with_p_up = len(filtered_df_p_Yes_up)

num_users_no_h_with_h_up = len(filtered_df_h_up)
num_users_Yes_h_with_h_up = len(filtered_df_h_Yes_up)

print(f'Number of users who said "No" in a_Scam use Upay and faced "Scam": {num_users_no_scam_with_scam_up}')
print(f'Number of users who said "Yes" in a_Scam use Upay and faced "Scam": {num_users_Yes_scam_with_scam_up}\n')

print(f'Number of users who said "No" in a_Fraud use Upay and faced "Fraud": {num_users_no_fraud_with_fraud_up}')
print(f'Number of users who said "Yes" in a_Fraud use Upay and faced "Fraud": {num_users_Yes_fraud_with_fraud_up}\n')

print(f'Number of users who said "No" in a_Identity_Theft use Upay and faced "Identity Theft": {num_users_no_IDT_with_IDT_up}')
print(f'Number of users who said "Yes" in a_Identity_Theft use Upay and faced "Identity Theft": {num_users_Yes_IDT_with_IDT_up}\n')

print(f'Number of users who said "No" in a_Phishing use Upay and faced "Phishing": {num_users_no_p_with_p_up}')
print(f'Number of users who said "Yes" in a_Phishing use Upay and faced "Phishing": {num_users_Yes_p_with_p_up}\n')

print(f'Number of users who said "No" in a_Hacking use Upay and faced "Hacking": {num_users_no_h_with_h_up}')
print(f'Number of users who said "Yes" in a_Hacking use Upay and faced "Hacking": {num_users_Yes_h_with_h_up}')
# Out:
# Number of users who said "No" in a_Scam use Upay and faced "Scam": 10
# Number of users who said "Yes" in a_Scam use Upay and faced "Scam": 0
#
# Number of users who said "No" in a_Fraud use Upay and faced "Fraud": 9
# Number of users who said "Yes" in a_Fraud use Upay and faced "Fraud": 0
#
# Number of users who said "No" in a_Identity_Theft use Upay and faced "Identity Theft": 9
# Number of users who said "Yes" in a_Identity_Theft use Upay and faced "Identity Theft": 0
#
# Number of users who said "No" in a_Phishing use Upay and faced "Phishing": 10
# Number of users who said "Yes" in a_Phishing use Upay and faced "Phishing": 0
#
# Number of users who said "No" in a_Hacking use Upay and faced "Hacking": 5
# Number of users who said "Yes" in a_Hacking use Upay and faced "Hacking": 1

# %%
categories_up = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
no_counts_up= [
    num_users_no_scam_with_scam_up,
    num_users_no_fraud_with_fraud_up,
    num_users_no_IDT_with_IDT_up,
    num_users_no_p_with_p_up,
    num_users_no_h_with_h_up
]
yes_counts_up = [
    num_users_Yes_scam_with_scam_up,
    num_users_Yes_fraud_with_fraud_up,
    num_users_Yes_IDT_with_IDT_up,
    num_users_Yes_p_with_p_up,
    num_users_Yes_h_with_h_up
]

total_counts_up = [n1 + n2 for n1, n2 in zip(no_counts_up, yes_counts_up)]
no_percentages = [n1 / total * 100 for n1, total in zip(no_counts_up, total_counts_up)]
yes_percentages = [n2 / total * 100 for n2, total in zip(yes_counts_up, total_counts_up)]

bar_width = 0.35

x = range(len(categories_up))

fig, ax = plt.subplots(figsize=(15, 8))

bar1 = ax.bar(x, no_counts_up, bar_width, label='No')
bar2 = ax.bar([i + bar_width for i in x], yes_counts_up, bar_width, label='Yes')

ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(categories_up)

for i, (n1, n2) in enumerate(zip(no_counts_up, yes_counts_up)):
    ax.text(i - bar_width / 2, max(n1, n2) + 5, f'{n1}', ha='center', va='bottom')

ax.set_xlabel('Problem Type')
ax.set_ylabel('Upay Users')
ax.legend()

ax2 = ax.twinx()
ax2.set_ylabel('Percentage')
ax2.set_ylim(0, 100)
for i, v in enumerate(no_percentages):
    ax2.text(i - bar_width / 2, v + 5, f'{v:.2f}%', ha='center', va='bottom', color='blue')
for i, v in enumerate(yes_percentages):
    ax2.text(i + bar_width * 1.5, v + 5, f'{v:.2f}%', ha='center', va='bottom', color='orange')

data_up = {
    'Problem Type': categories_up,
    'Count (No)': no_counts_up,
    'Percentage (No)': [100.0] * len(categories_up),
    'Count (Yes)': yes_counts_up,
    'Percentage (Yes)': yes_percentages
}

df_up = pd.DataFrame(data_up)

print(df_up)

plt.tight_layout()
plt.show()
# Out:
#      Problem Type  Count (No)  Percentage (No)  Count (Yes)  Percentage (Yes)
# 0            Scam          10            100.0            0          0.000000
# 1           Fraud           9            100.0            0          0.000000
# 2  Identity Theft           9            100.0            0          0.000000
# 3        Phishing          10            100.0            0          0.000000
# 4         Hacking           5            100.0            1         16.666667

# %%
filtered_df_scam_cf = df[(df['a_Scams'] == 'No') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Scam'))]
filtered_df_scam_Yes_cf = df[(df['a_Scams'] == 'Yes') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Scam'))]

filtered_df_fraud_cf = df[(df['a_Fraud'] == 'No') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Fraud'))]
filtered_df_fraud_Yes_cf = df[(df['a_Fraud'] == 'Yes') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Fraud'))]

filtered_df_IDT_cf = df[(df['a_Identity_Theft'] == 'No') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Identity Theft'))]
filtered_df_IDT_Yes_cf = df[(df['a_Identity_Theft'] == 'Yes') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Identity Theft'))]

filtered_df_p_cf = df[(df['a_Phishing'] == 'No') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Phishing'))]
filtered_df_p_Yes_cf = df[(df['a_Phishing'] == 'Yes') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Phishing'))]

filtered_df_h_cf = df[(df['a_Hacking'] == 'No') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Hacking'))]
filtered_df_h_Yes_cf = df[(df['a_Hacking'] == 'Yes') & (df['MBS'].str.contains('CellFin')) & (df['S_Problems'].str.contains('Hacking'))]

num_users_no_scam_with_scam_cf = len(filtered_df_scam_cf)
num_users_Yes_scam_with_scam_cf = len(filtered_df_scam_Yes_cf)

num_users_no_fraud_with_fraud_cf = len(filtered_df_fraud_cf)
num_users_Yes_fraud_with_fraud_cf = len(filtered_df_fraud_Yes_cf)

num_users_no_IDT_with_IDT_cf = len(filtered_df_IDT_cf)
num_users_Yes_IDT_with_IDT_cf = len(filtered_df_IDT_Yes_cf)

num_users_no_p_with_p_cf = len(filtered_df_p_cf)
num_users_Yes_p_with_p_cf = len(filtered_df_p_Yes_cf)

num_users_no_h_with_h_cf = len(filtered_df_h_cf)
num_users_Yes_h_with_h_cf = len(filtered_df_h_Yes_cf)

print(f'Number of users who said "No" in a_Scam use CellFin and faced "Scam": {num_users_no_scam_with_scam_cf}')
print(f'Number of users who said "Yes" in a_Scam use CellFin and faced "Scam": {num_users_Yes_scam_with_scam_cf}\n')

print(f'Number of users who said "No" in a_Fraud use CellFin and faced "Fraud": {num_users_no_fraud_with_fraud_cf}')
print(f'Number of users who said "Yes" in a_Fraud use CellFin and faced "Fraud": {num_users_Yes_fraud_with_fraud_cf}\n')

print(f'Number of users who said "No" in a_Identity_Theft use CellFin and faced "Identity Theft": {num_users_no_IDT_with_IDT_cf}')
print(f'Number of users who said "Yes" in a_Identity_Theft use CellFin and faced "Identity Theft": {num_users_Yes_IDT_with_IDT_cf}\n')

print(f'Number of users who said "No" in a_Phishing use CellFin and faced "Phishing": {num_users_no_p_with_p_cf}')
print(f'Number of users who said "Yes" in a_Phishing use CellFin and faced "Phishing": {num_users_Yes_p_with_p_cf}\n')

print(f'Number of users who said "No" in a_Hacking use CellFin and faced "Hacking": {num_users_no_h_with_h_cf}')
print(f'Number of users who said "Yes" in a_Hacking use CellFin and faced "Hacking": {num_users_Yes_h_with_h_cf}')
# Out:
# Number of users who said "No" in a_Scam use CellFin and faced "Scam": 33
# Number of users who said "Yes" in a_Scam use CellFin and faced "Scam": 0
#
# Number of users who said "No" in a_Fraud use CellFin and faced "Fraud": 30
# Number of users who said "Yes" in a_Fraud use CellFin and faced "Fraud": 0
#
# Number of users who said "No" in a_Identity_Theft use CellFin and faced "Identity Theft": 30
# Number of users who said "Yes" in a_Identity_Theft use CellFin and faced "Identity Theft": 0
#
# Number of users who said "No" in a_Phishing use CellFin and faced "Phishing": 32
# Number of users who said "Yes" in a_Phishing use CellFin and faced "Phishing": 0
#
# Number of users who said "No" in a_Hacking use CellFin and faced "Hacking": 4
# Number of users who said "Yes" in a_Hacking use CellFin and faced "Hacking": 0

# %%
categories_cf = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
no_counts_cf= [
    num_users_no_scam_with_scam_cf,
    num_users_no_fraud_with_fraud_cf,
    num_users_no_IDT_with_IDT_cf,
    num_users_no_p_with_p_cf,
    num_users_no_h_with_h_cf
]
yes_counts_cf = [
    num_users_Yes_scam_with_scam_cf,
    num_users_Yes_fraud_with_fraud_cf,
    num_users_Yes_IDT_with_IDT_cf,
    num_users_Yes_p_with_p_cf,
    num_users_Yes_h_with_h_cf
]

total_counts_cf = [n1 + n2 for n1, n2 in zip(no_counts_cf, yes_counts_cf)]
no_percentages = [n1 / total * 100 for n1, total in zip(no_counts_cf, total_counts_cf)]
yes_percentages = [n2 / total * 100 for n2, total in zip(yes_counts_cf, total_counts_cf)]

bar_width = 0.35

x = range(len(categories_cf))

fig, ax = plt.subplots(figsize=(15, 8))

bar1 = ax.bar(x, no_counts_cf, bar_width, label='No')
bar2 = ax.bar([i + bar_width for i in x], yes_counts_cf, bar_width, label='Yes')

ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(categories_cf)

for i, (n1, n2) in enumerate(zip(no_counts_cf, yes_counts_cf)):
    ax.text(i - bar_width / 2, max(n1, n2) + 5, f'{n1}', ha='center', va='bottom')

ax.set_xlabel('Problem Type')
ax.set_ylabel('CellFin Users')
ax.legend()

ax2 = ax.twinx()
ax2.set_ylabel('Percentage')
ax2.set_ylim(0, 100)
for i, v in enumerate(no_percentages):
    ax2.text(i - bar_width / 2, v + 5, f'{v:.2f}%', ha='center', va='bottom', color='blue')
for i, v in enumerate(yes_percentages):
    ax2.text(i + bar_width * 1.5, v + 5, f'{v:.2f}%', ha='center', va='bottom', color='orange')

data_cf = {
    'Problem Type': categories_cf,
    'Count (No)': no_counts_cf,
    'Percentage (No)': [100.0] * len(categories_cf),
    'Count (Yes)': yes_counts_cf,
    'Percentage (Yes)': yes_percentages
}

df_cf = pd.DataFrame(data_cf)

print(df_cf)

plt.tight_layout()
plt.show()
# Out:
#      Problem Type  Count (No)  Percentage (No)  Count (Yes)  Percentage (Yes)
# 0            Scam          33            100.0            0               0.0
# 1           Fraud          30            100.0            0               0.0
# 2  Identity Theft          30            100.0            0               0.0
# 3        Phishing          32            100.0            0               0.0
# 4         Hacking           4            100.0            0               0.0

# %%
filtered_df_OTP_no = df[(df['MC'] == 'No') & (df['O_Problems'].str.contains('OTP'))]
filtered_df_OTP_Yes = df[(df['MC'] == 'Yes') & (df['O_Problems'].str.contains('OTP'))]


num_users_no_OTP_with_OTP = len(filtered_df_OTP_no)
num_users_Yes_OTP_with_OTP = len(filtered_df_OTP_Yes)


print(f'Number of users who said "No" in MC and faced "OTP": {num_users_no_OTP_with_OTP}')
print(f'Number of users who said "Yes" in MC and faced "OTP": {num_users_Yes_OTP_with_OTP}')
# Out:
# Number of users who said "No" in MC and faced "OTP": 273
# Number of users who said "Yes" in MC and faced "OTP": 4

# %%
total_users = len(df)

categories = ["People Who Don't Clear Messages", "People Who Clear Messages"]
counts = [
    num_users_no_OTP_with_OTP,
    num_users_Yes_OTP_with_OTP,
]

percentages = [count / total_users * 100 for count in counts]

data = {
    'Category': categories,
    'Victim of OTP Problems': counts,
    'Percentage': percentages
}

df_table = pd.DataFrame(data)

print(df_table)

percentages = [count / total_users * 100 for count in counts]

plt.figure(figsize=(15, 9))
plt.plot(categories, counts, marker='o', linestyle='-', color='blue')
plt.xlabel('Category', fontweight='bold', fontsize=15)
plt.ylabel('Victim of OTP problem', fontweight='bold', fontsize=15)
plt.grid(True)

for i, (count, percentage) in enumerate(zip(counts, percentages)):
    plt.text(categories[i], count, f'{count}\n{percentage:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

plt.show()
# Out:
#                           Category  Victim of OTP Problems  Percentage
# 0  People Who Don't Clear Messages                     273       68.25
# 1        People Who Clear Messages                       4        1.00

# %%
male_users_no_OTP_with_OTP = filtered_df_OTP_no[filtered_df_OTP_no['Gender'] == 'Male']
female_users_no_OTP_with_OTP = filtered_df_OTP_no[filtered_df_OTP_no['Gender'] == 'Female']

male_users_Yes_OTP_with_OTP = filtered_df_OTP_Yes[filtered_df_OTP_Yes['Gender'] == 'Male']
female_users_Yes_OTP_with_OTP = filtered_df_OTP_Yes[filtered_df_OTP_Yes['Gender'] == 'Female']

num_male_users_no_OTP_with_OTP = len(male_users_no_OTP_with_OTP)
num_female_users_no_OTP_with_OTP = len(female_users_no_OTP_with_OTP)

num_male_users_Yes_OTP_with_OTP = len(male_users_Yes_OTP_with_OTP)
num_female_users_Yes_OTP_with_OTP = len(female_users_Yes_OTP_with_OTP)

print(f'Number of male users who said "No" in MC and faced "OTP": {num_male_users_no_OTP_with_OTP}')
print(f'Number of female users who said "No" in MC and faced "OTP": {num_female_users_no_OTP_with_OTP}')
print(f'Number of male users who said "Yes" in MC and faced "OTP": {num_male_users_Yes_OTP_with_OTP}')
print(f'Number of female users who said "Yes" in MC and faced "OTP": {num_female_users_Yes_OTP_with_OTP}')
# Out:
# Number of male users who said "No" in MC and faced "OTP": 170
# Number of female users who said "No" in MC and faced "OTP": 103
# Number of male users who said "Yes" in MC and faced "OTP": 4
# Number of female users who said "Yes" in MC and faced "OTP": 0

# %%
categories = ['Male (No)', 'Female (No)', 'Male (Yes)', 'Female (Yes)']
counts = [
    num_male_users_no_OTP_with_OTP,
    num_female_users_no_OTP_with_OTP,
    num_male_users_Yes_OTP_with_OTP,
    num_female_users_Yes_OTP_with_OTP
]

total_users = sum(counts)

percentages = [(count / total_users) * 100 if total_users != 0 else 0 for count in counts]

data = {'Gender and MC Response': categories, 'Count': counts, 'Percentage': percentages}
df = pd.DataFrame(data)

print(df.to_string(index=False))

bar_width = 0.5

x = range(len(categories))

fig, ax = plt.subplots(figsize=(10, 6))

bars = ax.bar(x, counts, width=bar_width, color=['skyblue', 'lightgreen', 'skyblue', 'lightgreen'])

ax.set_xlabel('Gender and MC Response')
ax.set_ylabel('Count')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation=0, ha='right')

for i, (bar, count, percentage) in enumerate(zip(bars, counts, percentages)):
    ax.annotate(f'{count}\n{percentage:.2f}%', xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', fontsize=10, color='black')

plt.tight_layout()
plt.show()
# Out:
# Gender and MC Response  Count  Percentage
#              Male (No)    170   61.371841
#            Female (No)    103   37.184116
#             Male (Yes)      4    1.444043
#           Female (Yes)      0    0.000000

# %%
security_issues_columns = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']

security_issues_counts = df[security_issues_columns].sum()
security_issues_percentages = (security_issues_counts / len(df)) * 100

top_security_issues = security_issues_percentages.sort_values(ascending=False).head(3).index

subset_df = df[top_security_issues]

correlation_matrix = subset_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Pearson Correlation Heatmap for Top Security Issues')

correlation_table = subset_df.corr().round(2)

plt.figure(figsize=(6, 4))
plt.table(cellText=correlation_table.values, colLabels=correlation_table.columns, cellLoc='center', loc='center', colColours=['#f5f5f5']*len(correlation_table.columns))
plt.title('Correlation Values Table')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-9f6f0c777d88> in <cell line: 3>()
#       1 security_issues_columns = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
#       2
# ----> 3 security_issues_counts = df[security_issues_columns].sum()
#       4 security_issues_percentages = (security_issues_counts / len(df)) * 100
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
security_issues_columns = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']

security_issues_counts = df[security_issues_columns].sum()
security_issues_percentages = (security_issues_counts / len(df)) * 100

top_security_issues = security_issues_percentages.sort_values(ascending=False).head(3).index

subset_df = df[top_security_issues]

correlation_matrix = subset_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Pearson Correlation Heatmap for Top Security Issues')

correlation_table = subset_df.corr().round(2)

plt.figure(figsize=(6, 4))
plt.table(cellText=correlation_table.values, colLabels=correlation_table.columns, cellLoc='center', loc='center', colColours=['#f5f5f5']*len(correlation_table.columns))
plt.title('Correlation Values Table')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-9f6f0c777d88> in <cell line: 3>()
#       1 security_issues_columns = ['Scam', 'Fraud', 'Identity Theft', 'Phishing', 'Hacking']
#       2
# ----> 3 security_issues_counts = df[security_issues_columns].sum()
#       4 security_issues_percentages = (security_issues_counts / len(df)) * 100
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
other_issues_columns = ['OTP', 'QR Scan', 'Connectivity']

for col in other_issues_columns:
    df[col] = df.apply(lambda row: col in row['O_Problems'], axis=1).astype(int)

other_issues_counts = df[other_issues_columns].sum()

sort_other_issues_counts = other_issues_counts.sort_values(ascending=False)

total_other_issues = sort_other_issues_counts.sum()

other_issues_percentages = (sort_other_issues_counts / total_other_issues) * 100

other_issues_percentages_sorted = other_issues_percentages.sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(other_issues_percentages_sorted.index, other_issues_percentages_sorted)
plt.xlabel('Other Issues')
plt.ylabel('Percentage Level')
plt.xticks(rotation=0, ha='right')

for i, v in enumerate(other_issues_percentages_sorted):
    plt.text(i, v, f"{v:.2f}%", ha='center', va='bottom')

other_issues_counts_df = pd.DataFrame({
    'Other Issues': other_issues_percentages_sorted.index,
    'Count': sort_other_issues_counts.values,
    'Percentage': other_issues_percentages_sorted.values
})

print(other_issues_counts_df)

plt.tight_layout()
plt.show()
# Out:
#    Other Issues  Count  Percentage
# 0           OTP    277   50.090416
# 1       QR Scan    172   31.103074
# 2  Connectivity    104   18.806510

# %%
other_issues_columns = ['OTP', 'QR Scan', 'Connectivity']

other_issues_counts = df[other_issues_columns].sum()
other_issues_percentages = (other_issues_counts / len(df)) * 100

top_other_issues = other_issues_percentages.sort_values(ascending=False).head(3).index

subset_df = df[top_other_issues]

correlation_matrix = subset_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Pearson Correlation Heatmap for Other Issues')

correlation_table = subset_df.corr().round(2)

plt.figure(figsize=(6, 4))
plt.table(cellText=correlation_table.values, colLabels=correlation_table.columns, cellLoc='center', loc='center', colColours=['#f5f5f5']*len(correlation_table.columns))
plt.title('Correlation Values Table')
plt.axis('off')
plt.show()

# %%
filtered_df = df[(df['S_Problems'] != 'None') & (df['O_Problems'] != 'None')]

satisfaction_ratings = filtered_df['S_ratings']

mean_satisfaction = satisfaction_ratings.mean()

median_satisfaction = satisfaction_ratings.median()

satisfaction_statistics = satisfaction_ratings.describe()

print(f"Mean Satisfaction Level: {mean_satisfaction}")
print(f"Median Satisfaction Level: {median_satisfaction}")
print("\nSatisfaction Level Statistics:")
print(satisfaction_statistics)

# %%
filtered_df = df[(df['S_Problems'] != 'None') & (df['O_Problems'] != 'None')]

satisfaction_ratings = filtered_df['S_ratings']

plt.figure(figsize=(10, 6))
n, bins, patches = plt.hist(satisfaction_ratings, bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Satisfaction Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Satisfaction Ratings')
plt.grid(True)

total_ratings = len(satisfaction_ratings)
for count, bin_edge in zip(n, bins):
    percentage = (count / total_ratings) * 100
    plt.text(bin_edge + 0.5, count, f'{percentage:.2f}%', ha='center', va='bottom', fontsize=10)

plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already loaded your DataFrame 'df'

correlation_matrix = df.corr(method='pearson')

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)

# Display the correlation values in a table
plt.title('Correlation Heatmap')
plt.show()

# Display the correlation values in a table
correlation_table = df.corr()
print("Correlation Table:")
print(correlation_table)
# Out:
# Correlation Table:
#            MC       OTP
# MC   1.000000 -0.929177
# OTP -0.929177  1.000000
